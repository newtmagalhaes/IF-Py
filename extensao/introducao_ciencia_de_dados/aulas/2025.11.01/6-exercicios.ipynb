# %% [markdown]
# ## Parte 2
#
# exercício prático.
#
# a) aplique `factorize()` e mostre os resultados.
#
# b) explique se essa codificação seria apropriada para um modelo de regressão linear.

# %%
import pandas as pd

dados = pd.Series(['gato', 'cachorro', 'passaro', 'gato', 'cachorro'])
