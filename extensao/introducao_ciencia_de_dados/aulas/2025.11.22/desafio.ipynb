# %%
import pandas as pd
from pprint import pprint

INPUT_FILE = 'downloads/microdados_enem_2024/DADOS/RESULTADOS_2024_CE.csv'

df = pd.read_csv(INPUT_FILE)
pprint(df.columns)
df.head()
# Out:
# Index(['NU_SEQUENCIAL', 'NU_ANO', 'CO_ESCOLA', 'CO_MUNICIPIO_ESC',
#        'NO_MUNICIPIO_ESC', 'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
#        'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
#        'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA', 'TP_PRESENCA_CN',
#        'TP_PRESENCA_CH', 'TP_PRESENCA_LC', 'TP_PRESENCA_MT', 'CO_PROVA_CN',
#        'CO_PROVA_CH', 'CO_PROVA_LC', 'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH',
#        'NU_NOTA_LC', 'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
#        'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA', 'TX_GABARITO_CN',
#        'TX_GABARITO_CH', 'TX_GABARITO_LC', 'TX_GABARITO_MT',
#        'TP_STATUS_REDACAO', 'NU_NOTA_COMP1', 'NU_NOTA_COMP2', 'NU_NOTA_COMP3',
#        'NU_NOTA_COMP4', 'NU_NOTA_COMP5', 'NU_NOTA_REDACAO'],
#       dtype='object')
#    NU_SEQUENCIAL  NU_ANO   CO_ESCOLA  CO_MUNICIPIO_ESC NO_MUNICIPIO_ESC  \
# 0         206403    2024  23052929.0         2301406.0          Aratuba
# 1        2262755    2024         NaN               NaN              NaN
# 2         500706    2024  23007648.0         2307809.0            Marco
# 3        1847098    2024         NaN               NaN              NaN
# 4        2023802    2024  23277971.0         2302701.0     Campos Sales
#
#    CO_UF_ESC SG_UF_ESC  TP_DEPENDENCIA_ADM_ESC  TP_LOCALIZACAO_ESC  \
# 0       23.0        CE                     2.0                 1.0
# 1        NaN       NaN                     NaN                 NaN
# 2       23.0        CE                     2.0                 1.0
# 3        NaN       NaN                     NaN                 NaN
# 4       23.0        CE                     2.0                 2.0
#
#    TP_SIT_FUNC_ESC  ...                                 TX_GABARITO_CH  \
# 0              1.0  ...  CECEBEBCDBADDEBBABCDCAECEDADBAEABEADCEDADACBC
# 1              NaN  ...                                            NaN
# 2              1.0  ...  DADABCDCECEDEBBBEBCDBADACBCADCEBEADBAECAECEDA
# 3              NaN  ...  DADABCDCECEDEBBBEBCDBADACBCADCEBEADBAECAECEDA
# 4              1.0  ...                                            NaN
#
#                                       TX_GABARITO_LC  \
# 0  CAAAECDDDAECBECEDDCBDEDDCECBDCBCEADBBDBDDCBEDA...
# 1                                                NaN
# 2  AACEADDDACDADECBBDBEEBDDECCBEDDCADBBDEBCEBDCEC...
# 3  AACEADDDACDADECBBDBEEBDDECCBEDDCADBBDEBCEBDCEC...
# 4                                                NaN
#
#                                   TX_GABARITO_MT TP_STATUS_REDACAO  \
# 0  CECEBEDADCAADECDBBCEBDCCCACABBABBADDDCEADBBCE               1.0
# 1                                            NaN               NaN
# 2  DBCECEACADABBECBEDADCCDCCABBBCECEBCEADABBADDD               1.0
# 3  DBCECEACADABBECBEDADCCDCCABBBCECEBCEADABBADDD               1.0
# 4                                            NaN               NaN
#
#    NU_NOTA_COMP1  NU_NOTA_COMP2  NU_NOTA_COMP3  NU_NOTA_COMP4  NU_NOTA_COMP5  \
# 0           80.0           60.0           60.0           80.0           20.0
# 1            NaN            NaN            NaN            NaN            NaN
# 2          160.0          200.0          160.0          200.0          160.0
# 3          140.0          200.0          160.0          140.0          160.0
# 4            NaN            NaN            NaN            NaN            NaN
#
#    NU_NOTA_REDACAO
# 0            300.0
# 1              NaN
# 2            880.0
# 3            800.0
# 4              NaN
#
# [5 rows x 42 columns]

# %%
df.head().transpose()
# Out:
#                                                                         0  \
# NU_SEQUENCIAL                                                      206403
# NU_ANO                                                               2024
# CO_ESCOLA                                                      23052929.0
# CO_MUNICIPIO_ESC                                                2301406.0
# NO_MUNICIPIO_ESC                                                  Aratuba
# CO_UF_ESC                                                            23.0
# SG_UF_ESC                                                              CE
# TP_DEPENDENCIA_ADM_ESC                                                2.0
# TP_LOCALIZACAO_ESC                                                    1.0
# TP_SIT_FUNC_ESC                                                       1.0
# CO_MUNICIPIO_PROVA                                                2301406
# NO_MUNICIPIO_PROVA                                                Aratuba
# CO_UF_PROVA                                                            23
# SG_UF_PROVA                                                            CE
# TP_PRESENCA_CN                                                          1
# TP_PRESENCA_CH                                                          1
# TP_PRESENCA_LC                                                          1
# TP_PRESENCA_MT                                                          1
# CO_PROVA_CN                                                        1420.0
# CO_PROVA_CH                                                        1383.0
# CO_PROVA_LC                                                        1395.0
# CO_PROVA_MT                                                        1408.0
# NU_NOTA_CN                                                          436.8
# NU_NOTA_CH                                                          377.8
# NU_NOTA_LC                                                          423.4
# NU_NOTA_MT                                                          427.1
# TX_RESPOSTAS_CN             CAABADDBBBACACACDEABDBABDDCCBACDCCBAACCABCBAC
# TX_RESPOSTAS_CH             BEABBCDABCDBAEEBDDABCCDAADDABACDDAB..........
# TX_RESPOSTAS_LC             BCADBCDCEDBDDBDDCDBCBB*BBDEAEEBCDCABBDDAAECEE
# TX_RESPOSTAS_MT             CBDCCADBBECCBADEACCBDCACECDDABBDBADBAAEDBCCAB
# TP_LINGUA                                                               1
# TX_GABARITO_CN              CAEDAACCAEEXCBBAEDBBCAACDEDCBCEECAAEDDDEBBDDB
# TX_GABARITO_CH              CECEBEBCDBADDEBBABCDCAECEDADBAEABEADCEDADACBC
# TX_GABARITO_LC          CAAAECDDDAECBECEDDCBDEDDCECBDCBCEADBBDBDDCBEDA...
# TX_GABARITO_MT              CECEBEDADCAADECDBBCEBDCCCACABBABBADDDCEADBBCE
# TP_STATUS_REDACAO                                                     1.0
# NU_NOTA_COMP1                                                        80.0
# NU_NOTA_COMP2                                                        60.0
# NU_NOTA_COMP3                                                        60.0
# NU_NOTA_COMP4                                                        80.0
# NU_NOTA_COMP5                                                        20.0
# NU_NOTA_REDACAO                                                     300.0
#
#                                 1  \
# NU_SEQUENCIAL             2262755
# NU_ANO                       2024
# CO_ESCOLA                     NaN
# CO_MUNICIPIO_ESC              NaN
# NO_MUNICIPIO_ESC              NaN
# CO_UF_ESC                     NaN
# SG_UF_ESC                     NaN
# TP_DEPENDENCIA_ADM_ESC        NaN
# TP_LOCALIZACAO_ESC            NaN
# TP_SIT_FUNC_ESC               NaN
# CO_MUNICIPIO_PROVA        2304400
# NO_MUNICIPIO_PROVA      Fortaleza
# CO_UF_PROVA                    23
# SG_UF_PROVA                    CE
# TP_PRESENCA_CN                  0
# TP_PRESENCA_CH                  0
# TP_PRESENCA_LC                  0
# TP_PRESENCA_MT                  0
# CO_PROVA_CN                   NaN
# CO_PROVA_CH                   NaN
# CO_PROVA_LC                   NaN
# CO_PROVA_MT                   NaN
# NU_NOTA_CN                    NaN
# NU_NOTA_CH                    NaN
# NU_NOTA_LC                    NaN
# NU_NOTA_MT                    NaN
# TX_RESPOSTAS_CN               NaN
# TX_RESPOSTAS_CH               NaN
# TX_RESPOSTAS_LC               NaN
# TX_RESPOSTAS_MT               NaN
# TP_LINGUA                       1
# TX_GABARITO_CN                NaN
# TX_GABARITO_CH                NaN
# TX_GABARITO_LC                NaN
# TX_GABARITO_MT                NaN
# TP_STATUS_REDACAO             NaN
# NU_NOTA_COMP1                 NaN
# NU_NOTA_COMP2                 NaN
# NU_NOTA_COMP3                 NaN
# NU_NOTA_COMP4                 NaN
# NU_NOTA_COMP5                 NaN
# NU_NOTA_REDACAO               NaN
#
#                                                                         2  \
# NU_SEQUENCIAL                                                      500706
# NU_ANO                                                               2024
# CO_ESCOLA                                                      23007648.0
# CO_MUNICIPIO_ESC                                                2307809.0
# NO_MUNICIPIO_ESC                                                    Marco
# CO_UF_ESC                                                            23.0
# SG_UF_ESC                                                              CE
# TP_DEPENDENCIA_ADM_ESC                                                2.0
# TP_LOCALIZACAO_ESC                                                    1.0
# TP_SIT_FUNC_ESC                                                       1.0
# CO_MUNICIPIO_PROVA                                                2307809
# NO_MUNICIPIO_PROVA                                                  Marco
# CO_UF_PROVA                                                            23
# SG_UF_PROVA                                                            CE
# TP_PRESENCA_CN                                                          1
# TP_PRESENCA_CH                                                          1
# TP_PRESENCA_LC                                                          1
# TP_PRESENCA_MT                                                          1
# CO_PROVA_CN                                                        1422.0
# CO_PROVA_CH                                                        1384.0
# CO_PROVA_LC                                                        1396.0
# CO_PROVA_MT                                                        1410.0
# NU_NOTA_CN                                                          497.4
# NU_NOTA_CH                                                          483.3
# NU_NOTA_LC                                                          535.2
# NU_NOTA_MT                                                          514.9
# TX_RESPOSTAS_CN             ACBEDACBEDACBEDACBEDACBEDACBEDACBEDACBEDACBED
# TX_RESPOSTAS_CH             EEDEEDABAABDEADBECEACBAABCEAEBAEEACBBCAAECBEA
# TX_RESPOSTAS_LC             DCEDCDADECBBDAECADDABDEEEDBDCDBDEBAADDEECCBCA
# TX_RESPOSTAS_MT             ACBEDACEEDACBEDACBEDACBEDACBEDACBEDACBEDACBED
# TP_LINGUA                                                               1
# TX_GABARITO_CN              BBCEDBBAEXCCAEDDBCAEDAACAAEDDDEBBECBCEEDCAACD
# TX_GABARITO_CH              DADABCDCECEDEBBBEBCDBADACBCADCEBEADBAECAECEDA
# TX_GABARITO_LC          AACEADDDACDADECBBDBEEBDDECCBEDDCADBBDEBCEBDCEC...
# TX_GABARITO_MT              DBCECEACADABBECBEDADCCDCCABBBCECEBCEADABBADDD
# TP_STATUS_REDACAO                                                     1.0
# NU_NOTA_COMP1                                                       160.0
# NU_NOTA_COMP2                                                       200.0
# NU_NOTA_COMP3                                                       160.0
# NU_NOTA_COMP4                                                       200.0
# NU_NOTA_COMP5                                                       160.0
# NU_NOTA_REDACAO                                                     880.0
#
#                                                                         3  \
# NU_SEQUENCIAL                                                     1847098
# NU_ANO                                                               2024
# CO_ESCOLA                                                             NaN
# CO_MUNICIPIO_ESC                                                      NaN
# NO_MUNICIPIO_ESC                                                      NaN
# CO_UF_ESC                                                             NaN
# SG_UF_ESC                                                             NaN
# TP_DEPENDENCIA_ADM_ESC                                                NaN
# TP_LOCALIZACAO_ESC                                                    NaN
# TP_SIT_FUNC_ESC                                                       NaN
# CO_MUNICIPIO_PROVA                                                2302503
# NO_MUNICIPIO_PROVA                                            Brejo Santo
# CO_UF_PROVA                                                            23
# SG_UF_PROVA                                                            CE
# TP_PRESENCA_CN                                                          1
# TP_PRESENCA_CH                                                          1
# TP_PRESENCA_LC                                                          1
# TP_PRESENCA_MT                                                          1
# CO_PROVA_CN                                                        1422.0
# CO_PROVA_CH                                                        1384.0
# CO_PROVA_LC                                                        1396.0
# CO_PROVA_MT                                                        1410.0
# NU_NOTA_CN                                                          630.4
# NU_NOTA_CH                                                          658.4
# NU_NOTA_LC                                                          619.9
# NU_NOTA_MT                                                          495.0
# TX_RESPOSTAS_CN             BDEEDABAEBBEADDDBEEEDCBCABBDEDEBBBCBCEBDCBBCA
# TX_RESPOSTAS_CH             AADABCDBECEDEDBBEBEDBADECBEADDEEEACBAEBAECEDA
# TX_RESPOSTAS_LC             AACEBDADECBBDBEEBDCDACAEDDCADBBDEBDCBDBECCBBC
# TX_RESPOSTAS_MT             BBCCCAACBBCBDBBACBBBBCBCCBCCBCEAEEACCABBBCCEC
# TP_LINGUA                                                               0
# TX_GABARITO_CN              BBCEDBBAEXCCAEDDBCAEDAACAAEDDDEBBECBCEEDCAACD
# TX_GABARITO_CH              DADABCDCECEDEBBBEBCDBADACBCADCEBEADBAECAECEDA
# TX_GABARITO_LC          AACEADDDACDADECBBDBEEBDDECCBEDDCADBBDEBCEBDCEC...
# TX_GABARITO_MT              DBCECEACADABBECBEDADCCDCCABBBCECEBCEADABBADDD
# TP_STATUS_REDACAO                                                     1.0
# NU_NOTA_COMP1                                                       140.0
# NU_NOTA_COMP2                                                       200.0
# NU_NOTA_COMP3                                                       160.0
# NU_NOTA_COMP4                                                       140.0
# NU_NOTA_COMP5                                                       160.0
# NU_NOTA_REDACAO                                                     800.0
#
#                                    4
# NU_SEQUENCIAL                2023802
# NU_ANO                          2024
# CO_ESCOLA                 23277971.0
# CO_MUNICIPIO_ESC           2302701.0
# NO_MUNICIPIO_ESC        Campos Sales
# CO_UF_ESC                       23.0
# SG_UF_ESC                         CE
# TP_DEPENDENCIA_ADM_ESC           2.0
# TP_LOCALIZACAO_ESC               2.0
# TP_SIT_FUNC_ESC                  1.0
# CO_MUNICIPIO_PROVA           2302701
# NO_MUNICIPIO_PROVA      Campos Sales
# CO_UF_PROVA                       23
# SG_UF_PROVA                       CE
# TP_PRESENCA_CN                     0
# TP_PRESENCA_CH                     0
# TP_PRESENCA_LC                     0
# TP_PRESENCA_MT                     0
# CO_PROVA_CN                      NaN
# CO_PROVA_CH                      NaN
# CO_PROVA_LC                      NaN
# CO_PROVA_MT                      NaN
# NU_NOTA_CN                       NaN
# NU_NOTA_CH                       NaN
# NU_NOTA_LC                       NaN
# NU_NOTA_MT                       NaN
# TX_RESPOSTAS_CN                  NaN
# TX_RESPOSTAS_CH                  NaN
# TX_RESPOSTAS_LC                  NaN
# TX_RESPOSTAS_MT                  NaN
# TP_LINGUA                          1
# TX_GABARITO_CN                   NaN
# TX_GABARITO_CH                   NaN
# TX_GABARITO_LC                   NaN
# TX_GABARITO_MT                   NaN
# TP_STATUS_REDACAO                NaN
# NU_NOTA_COMP1                    NaN
# NU_NOTA_COMP2                    NaN
# NU_NOTA_COMP3                    NaN
# NU_NOTA_COMP4                    NaN
# NU_NOTA_COMP5                    NaN
# NU_NOTA_REDACAO                  NaN
